# %% [markdown]
# # PATIENT INFORMATION & HEALTH INSURANCE COST
# ## **DATA TRANSFORMATION (3)**
# **Transformation non-numeric columns to numeric columns.**

# %%
import numpy as np
import pandas as pd

# %%
cleaned_data = pd.read_csv("cleaned_data.csv")
data = cleaned_data.copy()

data.head()
# Out:
#    Unnamed: 0  age     sex     bmi  children smoker     region      charges
# 0           0   19  female  27.900         0    yes  southwest  16884.92400
# 1           1   18    male  33.770         1     no  southeast   1725.55230
# 2           2   28    male  33.000         3     no  southeast   4449.46200
# 3           3   33    male  22.705         0     no  northwest  21984.47061
# 4           4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.drop(["Unnamed: 0"], axis = 1, inplace = True)

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
print("Total non-numeric columns:", len(data.select_dtypes("object").columns), "\n")

for column in data.select_dtypes("object").columns:
    print(column, ":", list(data[column].unique()),)
# Out:
# Total non-numeric columns: 3
#
# sex : ['female', 'male']
# smoker : ['yes', 'no']
# region : ['southwest', 'southeast', 'northwest', 'northeast']

# %% [markdown]
# ## **Label Encoding**
# **Label Encoding is a popular encoding technique for handling categorical variables. In this technique, each label is assigned a unique integer based on alphabetical ordering.**

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

data["sex"] = LE.fit_transform(data["sex"])
data["smoker"] = LE.fit_transform(data["smoker"])

# %% [markdown]
# |**sex**|**smoker**|
# |--------|----------|
# | **0 : female**|**0 : no**|
# | **1 : male**  | **1 : yes**|

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %% [markdown]
# ## **One-Hot Encoding**
# **One-Hot Encoding is another popular technique for treating categorical variables. It simply creates additional features based on the number of unique values in the categorical feature. Every unique value in the category will be added as a feature.**

# %%
data = pd.get_dummies(data, columns = ["region"], prefix = ["region"], drop_first = True)

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker      charges  region_northwest  \
# 0   19    0  27.900         0       1  16884.92400                 0
# 1   18    1  33.770         1       0   1725.55230                 0
# 2   28    1  33.000         3       0   4449.46200                 0
# 3   33    1  22.705         0       0  21984.47061                 1
# 4   32    1  28.880         0       0   3866.85520                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %% [markdown]
# ### **Correlations Between Features**

# %%
corr = data.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_965b5f68_364e_11eb_91cb_9d85f848caeerow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow0_col2 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow0_col3 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow0_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow0_col5 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow0_col6 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow0_col7 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow0_col8 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow1_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow1_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow1_col3 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow1_col4 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow1_col5 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow1_col6 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow1_col7 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow1_col8 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow2_col0 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow2_col1 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow2_col3 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow2_col4 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow2_col5 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow2_col6 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow2_col7 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow2_col8 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow3_col0 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow3_col1 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow3_col2 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow3_col4 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow3_col5 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow3_col6 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow3_col7 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow3_col8 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow4_col1 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow4_col2 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow4_col3 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow4_col5 {
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow4_col6 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow4_col7 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow4_col8 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow5_col0 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow5_col1 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow5_col2 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow5_col3 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow5_col4 {
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow5_col6 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow5_col7 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow5_col8 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow6_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow6_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow6_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow6_col3 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow6_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_965b5f68_364e_11eb_91cb_9d85f848caeerow6_col5 {
#             background-color:  #fef6fb;
#             color:  #000000;

# %%
data.to_csv("final_data.csv")
